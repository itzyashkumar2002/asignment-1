# %%
# mobile verification asignment

class mobile:
  def __init__(self,name,ram,model,price,display):
    self.name=name
    self.ram=ram
    self.model=model
    self.price=price
    self.display=display
    print("constructor is executed")
  def displayr(self):
      print(self.name,"display=",self.display)

realme=mobile(name="realme",ram=" 4 - 64",model="13 pro",price="19500",display="amrolled")
realme.displayr()
print(realme.name,"\n",realme.ram,"\n",realme.model,"\n",realme.price,"\n")
# Out:
# constructor is executed
# realme display= amrolled
# realme
#   4 - 64
#  13 pro
#  19500

# %%
class mall:
  def __init__(self,name,adress,city,state):
    self.name=name
    self.state=state
    self.adress=adress
    self.city=city
    print("constructoris executed:")

  def states(self):
    print(self.name,"state=",self.state)

eminent=mall(name="eminent",state="haryana",city="hisar",adress="AGRESSION BHAWAN ")
eminent.states()
print(eminent.name,"\n",eminent.state,"\n",eminent.city,"\n",eminent.adress)
# Out:
# constructoris executed:
# eminent state= haryana
# eminent
#  haryana
#  hisar
#  AGRESSION BHAWAN

# %%
#class variable
class animal:
  #isntance vaiable in constructor
  def __init__(self,name,weight,sound,colour):
    self.name=name
    self.weight=weight
    self.colour=colour
    self.sound=sound
    print("constructor is executed ")

  #method
  def sounds(self):
        print(self.name,"sound =",self.sound)

cat=animal(name="pussy",sound="miyoon miyoon",weight="10 grm",colour="white")
cat.sounds()
print(cat.name,"\n",cat.weight,"\n",cat.colour)


dog=animal(name="bhorra",sound="bhaoww bhaoww",weight="92500 grm",colour="brown")
dog.sounds()
print(dog.name,"\n",dog.weight,"\n",dog.colour)
# Out:
# constructor is executed
# pussy sound = miyoon miyoon
# pussy
#  10 grm
#  white
# constructor is executed
# bhorra sound = bhaoww bhaoww
# bhorra
#  92500 grm
#  brown
