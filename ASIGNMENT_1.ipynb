# %%
student1={"name":["maohit","rohit","kaloo","pappu","baabu"], "marks":[41,54,65,89,13], "subject":"physics"}
student1["name"].insert(5,"raju")
student1["marks"].insert(5,25)
print(student1)

student1["name"].insert(0,"raju")
student1["marks"].insert(0,25)
print(student1)

student1["name"][2]="bhoora"
print(student1)
# Out:
# {'name': ['maohit', 'rohit', 'kaloo', 'pappu', 'baabu', 'raju'], 'marks': [41, 54, 65, 89, 13, 25], 'subject': 'physics'}
# {'name': ['raju', 'maohit', 'rohit', 'kaloo', 'pappu', 'baabu', 'raju'], 'marks': [25, 41, 54, 65, 89, 13, 25], 'subject': 'physics'}
# {'name': ['raju', 'maohit', 'bhoora', 'kaloo', 'pappu', 'baabu', 'raju'], 'marks': [25, 41, 54, 65, 89, 13, 25], 'subject': 'physics'}
