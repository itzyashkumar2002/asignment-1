# %%
# for even and odd numbers


num=int(input("enter your number"))
if num%2==0:
  print("even muber")
else:
  print("odd number")
# Out:
# enter your number45
# odd number

# %%
# for voting list
age=int(input("plz insert your option :"))

if age >= 0 and age <= 5:
    print("Go to sleep")
elif age >= 6 and age <= 17:
    print("Go to play")
elif age >= 18 and age <= 75:
    print("You can vote")
else:
    print("Go for rest")
# Out:
# plz insert your option :56
# You can vote
